# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.tseries.offsets import BDay
from pandas_datareader import data

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Read CSV into pandas
data = pd.read_excel(r"universitymatplottask.xlsx")
data.head()
df = pd.DataFrame(data)

name = df['department'].head(12)
price = df['Amount'].head(12)

# Figure Size
fig = plt.figure(figsize =(10, 7))

# Horizontal Bar Plot
plt.bar(name[0:10], price[0:10])

# Show Plot
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Read CSV into pandas
data = pd.read_excel(r"universitymatplottask.xlsx")
df = pd.DataFrame(data)


name = df['department']
price = df['Amount']



# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))

# Horizontal Bar Plot
ax.barh(name, price)

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
	ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
		linestyle ='-.', linewidth = 0.5,
		alpha = 0.2)

# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
	plt.text(i.get_width()+0.2, i.get_y()+0.5,
			str(round((i.get_width()), 2)),
			fontsize = 10, fontweight ='bold',
			color ='grey')

# Add Plot Title
ax.set_title('Department and their 6 year fee structure',
			loc ='left', )

# Add Text watermark
fig.text(0.9, 0.15, 'totals', fontsize = 12,
		color ='grey', ha ='right', va ='bottom',
		alpha = 0.7)

# Show Plot
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Read CSV into pandas
data = pd.read_excel(r"universitymatplottask.xlsx")
df = pd.DataFrame(data)


name = df['program']
price = df['Amount']



# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))

# Horizontal Bar Plot
ax.barh(name, price)

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
	ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
		linestyle ='-.', linewidth = 0.5,
		alpha = 0.2)

# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
	plt.text(i.get_width()+0.2, i.get_y()+0.5,
			str(round((i.get_width()), 2)),
			fontsize = 10, fontweight ='bold',
			color ='grey')

# Add Plot Title
ax.set_title('Program and their 6 year fee structure',
			loc ='left', )

# Add Text watermark
fig.text(0.9, 0.15, 'totals', fontsize = 12,
		color ='grey', ha ='right', va ='bottom',
		alpha = 0.7)

# Show Plot
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Read CSV into pandas
data = pd.read_excel(r"universitymatplottask.xlsx")
df = pd.DataFrame(data)


name = df['gender_dt']
price = df['Amount']



# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))

# Horizontal Bar Plot
ax.barh(name, price)

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
	ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
		linestyle ='-.', linewidth = 0.5,
		alpha = 0.2)

# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
	plt.text(i.get_width()+0.2, i.get_y()+0.5,
			str(round((i.get_width()), 2)),
			fontsize = 10, fontweight ='bold',
			color ='grey')

# Add Plot Title
ax.set_title('Department and their 6 year fee structure',
			loc ='left', )

# Add Text watermark
fig.text(0.9, 0.15, 'totals', fontsize = 12,
		color ='grey', ha ='right', va ='bottom',
		alpha = 0.7)

# Show Plot
plt.show()

# %%
names = df['department']

# %%
plt.plot(name, price, 'bs', names, 'g^')

# %%
data
# Out:
#      year department program  roll no   names  Voucher_ID  Amount      Status  \
# 0      18        ENG      BS        2  Hajira    19114618   18000        Paid
# 1      17        BIS      BS       56  Rimsha    19114620   24500        Paid
# 2      18         CS      BS       46    Syed    19114621   24000        Paid
# 3      18         CS      BS       59  Aleena    19114625   24000        Paid
# 4      17        BIS      BS       64  Sumbal    19114628    7000        Paid
# ...   ...        ...     ...      ...     ...         ...     ...         ...
# 1038   20        PSY      BS       41   Arooj    19116109    6000  Defaulting
# 1039   20        PSY      BS       49  Fatima    19116110    6000  Defaulting
# 1040   20        PSY      BS       50  Madiha    19115687   15000  Defaulting
# 1041   20        PSY      BS       54  Nazish    19115690   15000  Defaulting
# 1042   20        PSY      BS      109   Usman    19115745   12000  Defaulting
#
#      gender_dt
# 0       female
# ...

# %%
data = pandas.DataFrame(data={'val': values}, index=index).reset_index()
print(data)
fg = seaborn.factorplot(x='Group', y='val', hue='Mean', 
                        col='Sex', data=data, kind='bar')
fg.set_xlabels('')

# %%
import numpy as np
import pandas

import seaborn
seaborn.set(style='ticks') 
np.random.seed(0)

groups = ('Group 1', 'Group 2')
sexes = ('Male', 'Female')
means = ('Low', 'High')
index = pandas.MultiIndex.from_product(
    [groups, sexes, means], 
   names=['Group', 'Sex', 'Mean']
)

values = np.random.randint(low=20, high=100, size=len(index))
data = pandas.DataFrame(data={'val': values}, index=index).reset_index()
print(data)
# Out:
#      Group     Sex  Mean  val
# 0  Group 1    Male   Low   64
# 1  Group 1    Male  High   67
# 2  Group 1  Female   Low   84
# 3  Group 1  Female  High   87
# 4  Group 2    Male   Low   87
# 5  Group 2    Male  High   29
# 6  Group 2  Female   Low   41
# 7  Group 2  Female  High   56

# %%
#x=data['department']
#y=data['Amount']

fg = seaborn.factorplot(x='department', y='Amount', hue='program', 
                        col='gender_dt', data=data, kind='bar')
fg.set_xlabels('')
# Out:
# C:\Users\MUZAMMIL YOUSAF\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
fg = seaborn.factorplot(x='year', y='Amount', hue='program', 
                        col='gender_dt', data=data, kind='bar')
fg.set_xlabels('')
# Out:
# C:\Users\MUZAMMIL YOUSAF\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
fg = seaborn.factorplot(x='year', y='Amount', hue='program', 
                        col='department', data=data, kind='bar')
fg.set_xlabels('')
# Out:
# C:\Users\MUZAMMIL YOUSAF\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
fg = seaborn.factorplot(x='year', y='Amount', hue='program', 
                        col='Status', data=data, kind='bar')
fg.set_xlabels('')

# %%
fg = seaborn.factorplot(x='year', y='Amount', hue='program', 
                        col='Status', data=data, kind='bar')
fg.set_xlabels('')
